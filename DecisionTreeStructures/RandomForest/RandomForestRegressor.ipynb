# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\merve\Desktop\PythonProject\15-gym_crowdedness.csv')

# %%
df.head()
# Out:
#    number_people                       date  timestamp  day_of_week  \
# 0             37  2015-08-14 17:00:11-07:00      61211            4
# 1             45  2015-08-14 17:20:14-07:00      62414            4
# 2             40  2015-08-14 17:30:15-07:00      63015            4
# 3             44  2015-08-14 17:40:16-07:00      63616            4
# 4             45  2015-08-14 17:50:17-07:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour
# 0                   0      8    17
# 1                   0      8    17
# 2                   0      8    17
# 3                   0      8    17
# ...

# %%
df.columns
# Out:
# Index(['number_people', 'date', 'timestamp', 'day_of_week', 'is_weekend',
#        'is_holiday', 'temperature', 'is_start_of_semester',
#        'is_during_semester', 'month', 'hour'],
#       dtype='str')

# %%
df.info() #her şey numeric
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62184 entries, 0 to 62183
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   number_people         62184 non-null  int64
#  1   date                  62184 non-null  str
#  2   timestamp             62184 non-null  int64
#  3   day_of_week           62184 non-null  int64
#  4   is_weekend            62184 non-null  int64
#  5   is_holiday            62184 non-null  int64
#  6   temperature           62184 non-null  float64
#  7   is_start_of_semester  62184 non-null  int64
#  8   is_during_semester    62184 non-null  int64
#  9   month                 62184 non-null  int64
#  10  hour                  62184 non-null  int64
# dtypes: float64(1), int64(9), str(1)
# memory usage: 5.2 MB

# %%
df.shape
# Out:
# (62184, 11)

# %%
df.describe()
# Out:
#        number_people     timestamp   day_of_week    is_weekend    is_holiday  \
# count   62184.000000  62184.000000  62184.000000  62184.000000  62184.000000
# mean       29.072543  45799.437958      2.982504      0.282870      0.002573
# std        22.689026  24211.275891      1.996825      0.450398      0.050660
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         9.000000  26624.000000      1.000000      0.000000      0.000000
# 50%        28.000000  46522.500000      3.000000      0.000000      0.000000
# 75%        43.000000  66612.000000      5.000000      1.000000      0.000000
# max       145.000000  86399.000000      6.000000      1.000000      1.000000
#
#         temperature  is_start_of_semester  is_during_semester         month  \
# count  62184.000000          62184.000000        62184.000000  62184.000000
# mean      58.557108              0.078831            0.660218      7.439824
# ...

# %%
df.isnull().sum()
# Out:
# number_people           0
# date                    0
# timestamp               0
# day_of_week             0
# is_weekend              0
# is_holiday              0
# temperature             0
# is_start_of_semester    0
# is_during_semester      0
# month                   0
# hour                    0
# dtype: int64

# %%
df['date']=pd.to_datetime(df['date'],utc=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62184 entries, 0 to 62183
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   number_people         62184 non-null  int64
#  1   date                  62184 non-null  datetime64[us, UTC]
#  2   timestamp             62184 non-null  int64
#  3   day_of_week           62184 non-null  int64
#  4   is_weekend            62184 non-null  int64
#  5   is_holiday            62184 non-null  int64
#  6   temperature           62184 non-null  float64
#  7   is_start_of_semester  62184 non-null  int64
#  8   is_during_semester    62184 non-null  int64
#  9   month                 62184 non-null  int64
#  10  hour                  62184 non-null  int64
# dtypes: datetime64[us, UTC](1), float64(1), int64(9)
# memory usage: 5.2 MB

# %%
df['date']
# Out:
# 0       2015-08-15 00:00:11+00:00
# 1       2015-08-15 00:20:14+00:00
# 2       2015-08-15 00:30:15+00:00
# 3       2015-08-15 00:40:16+00:00
# 4       2015-08-15 00:50:17+00:00
#                    ...
# 62179   2017-03-19 01:42:28+00:00
# 62180   2017-03-19 01:52:35+00:00
# 62181   2017-03-19 02:02:40+00:00
# 62182   2017-03-19 02:12:47+00:00
# 62183   2017-03-19 02:22:51+00:00
# Name: date, Length: 62184, dtype: datetime64[us, UTC]

# %%
df['date'].dt.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 62179    2017
# 62180    2017
# 62181    2017
# 62182    2017
# 62183    2017
# Name: date, Length: 62184, dtype: int32

# %%
df['date'].dt.month
# Out:
# 0        8
# 1        8
# 2        8
# 3        8
# 4        8
#         ..
# 62179    3
# 62180    3
# 62181    3
# 62182    3
# 62183    3
# Name: date, Length: 62184, dtype: int32

# %%
df['year']=df['date'].dt.year

# %%
df.head()
# Out:
#    number_people                      date  timestamp  day_of_week  \
# 0             37 2015-08-15 00:00:11+00:00      61211            4
# 1             45 2015-08-15 00:20:14+00:00      62414            4
# 2             40 2015-08-15 00:30:15+00:00      63015            4
# 3             44 2015-08-15 00:40:16+00:00      63616            4
# 4             45 2015-08-15 00:50:17+00:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour  year
# 0                   0      8    17  2015
# 1                   0      8    17  2015
# 2                   0      8    17  2015
# ...

# %%
df['year'].unique()
# Out:
# array([2015, 2016, 2017], dtype=int32)

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    number_people  timestamp  day_of_week  is_weekend  is_holiday  temperature  \
# 0             37      61211            4           0           0        71.76
# 1             45      62414            4           0           0        71.76
# 2             40      63015            4           0           0        71.76
# 3             44      63616            4           0           0        71.76
# 4             45      64217            4           0           0        71.76
#
#    is_start_of_semester  is_during_semester  month  hour  year
# 0                     0                   0      8    17  2015
# 1                     0                   0      8    17  2015
# 2                     0                   0      8    17  2015
# 3                     0                   0      8    17  2015
# 4                     0                   0      8    17  2015

# %%
sns.lineplot(data=df, x="hour", y="number_people", errorbar=None)
plt.title("Saatlik Ortalama İnsan Sayısı")
plt.show()

# %%
sns.barplot(data=df, x="day_of_week", y="number_people")
plt.title("Günlere göre insan sayısı")
plt.show()

# %%
sns.regplot(data=df, x="temperature", y="number_people")
plt.show()

# %%
sns.boxplot(data=df, x="is_holiday", y="number_people")
plt.title("Tatillerde insanlar")
plt.show()

# %%
sns.boxplot(data=df, x="is_start_of_semester", y="number_people")
plt.title("Dönem Başında İnsan Sayısı")
plt.show()

# %%
sns.boxplot(data=df, x="is_during_semester", y="number_people")
plt.title("Dönem İçinde İnsan Sayısı")
plt.show()

# %%
#dependent &independent feature

# %%
X=df.drop('number_people',axis=1)
y=df['number_people']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=15)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def calculate_model_metrics(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2 = r2_score(true, predicted)
    return mae, mse, rmse, r2

# %%
models = {
    "Linear Regression" : LinearRegression(),
    "Lasso": Lasso(),
    "Ridge" : Ridge(),
    "K-Neighbors Regressor"  : KNeighborsRegressor(),
    "Decision Tree" : DecisionTreeRegressor(),
    "Random Forest Regressor" : RandomForestRegressor()
}

# %%
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae, model_train_mse, model_train_rmse, model_train_r2 = calculate_model_metrics(y_train, y_train_pred)
    model_test_mae, model_test_mse ,model_test_rmse, model_test_r2 = calculate_model_metrics(y_test, y_test_pred)

    print(list(models.values())[i])

    print("Evaluation for Training Set")
    print("RMSE :", model_train_rmse)
    print("Mean Absolute Error :", model_train_mae)
    print("R2 Score :", model_train_r2)

    print("-----------------------------")

    print("Evaluation for Test Set")
    print("RMSE :", model_test_rmse)
    print("Mean Absolute Error :", model_test_mae)
    print("R2 Score :", model_test_r2)

    print("-----------------------------")
    print("\n")
# Out:
# LinearRegression()
# Evaluation for Training Set
# RMSE : 14.319420457001861
# Mean Absolute Error : 10.734870976416444
# R2 Score : 0.6001359834535362
# -----------------------------
# Evaluation for Test Set
# RMSE : 14.447023095453451
# Mean Absolute Error : 10.781563703532518
# R2 Score : 0.5991274908510482
# -----------------------------
#
#
# Lasso()
# Evaluation for Training Set
# RMSE : 14.569149340662554
# Mean Absolute Error : 10.945193370977654
# R2 Score : 0.5860672092756324
# -----------------------------
# Evaluation for Test Set
# RMSE : 14.703534672584084
# Mean Absolute Error : 10.970600794781967
# R2 Score : 0.5847658725440256
# -----------------------------
#
#
# Ridge()
# Evaluation for Training Set
# RMSE : 14.319425500132297
# Mean Absolute Error : 10.734715106977507
# R2 Score : 0.6001357017987372
# -----------------------------
# Evaluation for Test Set
# RMSE : 14.447050455441499
# Mean Absolute Error : 10.781395155476662
# R2 Score : 0.5991259724929239
# ...

# %% [markdown]
# **hyperparameter tuning**

# %%
knn_params = {"n_neighbors" : [2,3,10,20,40,50]}
rf_params = {
        "max_depth" : [5,8,10,15,None],
        "max_features" : ["sqrt", "log2", 5, 7, 10],
        "min_samples_split" : [2, 8, 12, 20],
        "n_estimators" : [100, 200, 500, 1000]
}

# %%
from sklearn.model_selection import RandomizedSearchCV
randomcv_models = [
    ("KNN", KNeighborsRegressor(), knn_params),
    ("RF", RandomForestRegressor(), rf_params)
        ]
#Birden fazla Karar Ağacını aynı anda eğitip, her birinin verdiği sonuçların ortalamasını alarak nihai tahmini yapar

# %%
for name, model, params in randomcv_models:
    randomcv = RandomizedSearchCV(estimator=model, param_distributions=params, n_iter = 100, cv = 3, n_jobs = -1)
    randomcv.fit(X_train, y_train)
    print("best params for :", name, randomcv.best_params_)
# Out:
# c:\Users\merve\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_search.py:324: UserWarning: The total space of parameters 6 is smaller than n_iter=100. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# best params for : KNN {'n_neighbors': 2}
# best params for : RF {'n_estimators': 500, 'min_samples_split': 2, 'max_features': 7, 'max_depth': None}

# %%
#best params for : KNN {'n_neighbors': 2}

# %%
models = {
    "K-Neighbors Regressor"  : KNeighborsRegressor(n_neighbors=2),
    "Random Forest Regressor" : RandomForestRegressor(n_estimators=500,
                                                     min_samples_split=2,
                                                      max_features=7,
                                                      max_depth = None)
}

# %%
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae, model_train_rmse, model_train_r2,a = calculate_model_metrics(y_train, y_train_pred)
    model_test_mae, model_test_rmse, model_test_r2 ,a= calculate_model_metrics(y_test, y_test_pred)
    print(list(models.values())[i])

    print("Evaluation for Training Set")
    print("RMSE :", model_train_rmse)
    print("Mean Absolute Error :", model_train_mae)
    print("R2 Score :", model_train_r2)

    print("-----------------------------")

    print("Evaluation for Test Set")
    print("RMSE :", model_test_rmse)
    print("Mean Absolute Error :", model_test_mae)
    print("R2 Score :", model_test_r2)

    print("-----------------------------")
    print("\n")
# Out:
# KNeighborsRegressor(n_neighbors=2)
# Evaluation for Training Set
# RMSE : 12.773955787126377
# Mean Absolute Error : 2.3176058150006433
# R2 Score : 3.574067121239664
# -----------------------------
# Evaluation for Test Set
# RMSE : 43.41644152836743
# Mean Absolute Error : 4.276791457609675
# R2 Score : 6.589115382839143
# -----------------------------
#
#
# RandomForestRegressor(max_features=7, n_estimators=500)
# Evaluation for Training Set
# RMSE : 4.686582768387265
# Mean Absolute Error : 1.4574375772668517
# R2 Score : 2.164851673530375
# -----------------------------
# Evaluation for Test Set
# RMSE : 36.72277672041667
# Mean Absolute Error : 4.044352905356147
# R2 Score : 6.059932072260931
# -----------------------------

# %%
df_clean1=df.copy()
kayit_yolu = r"C:\Users\merve\Desktop\PythonProject\DecisionTreeStructures\RandomForest\cleaned_15-gym_crowdedness.csv"
df_clean1.to_csv(kayit_yolu, index=False)
print(f"Temizlenmiş veri başarıyla kaydedildi: {kayit_yolu}")
# Out:
# Temizlenmiş veri başarıyla kaydedildi: C:\Users\merve\Desktop\PythonProject\DecisionTreeStructures\RandomForest\cleaned_15-gym_crowdedness.csv
