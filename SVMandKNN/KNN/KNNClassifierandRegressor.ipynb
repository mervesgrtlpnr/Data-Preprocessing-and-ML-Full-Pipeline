# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\merve\Desktop\PythonProject\12-health_risk_classification.csv')

# %%
# temizlenmiş data

# %%
df.head()
# Out:
#    bmi_score  blood_pressure_variation  activity_level_index  high_risk_flag
# 0   0.564223                  0.652825              1.262925               1
# 1  -1.692569                  2.981229             -0.180331               1
# 2   0.770383                  0.400475              1.365806               1
# 3   2.135007                  0.150832              3.084596               0
# 4   0.360342                  1.026132              1.251574               1

# %%
df.describe()
# Out:
#          bmi_score  blood_pressure_variation  activity_level_index  \
# count  1000.000000               1000.000000           1000.000000
# mean     -0.023702                  0.016769             -0.020771
# std       1.203694                  1.268761              1.392738
# min      -4.743951                 -2.587178             -4.999018
# 25%      -0.796655                 -0.981320             -1.057938
# 50%       0.142105                 -0.317137              0.204506
# 75%       0.956225                  1.017388              1.061181
# max       2.321480                  3.954873              3.477210
#
#        high_risk_flag
# count     1000.000000
# mean         0.498000
# std          0.500246
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %%
sns.scatterplot(x=df['blood_pressure_variation'],y=df['activity_level_index'],hue=df['high_risk_flag'])
plt.show()

# %%
#çok birbirinden ayrılan datalara sahip değiliz

# %%
df['high_risk_flag'].value_counts()
# Out:
# high_risk_flag
# 0    502
# 1    498
# Name: count, dtype: int64

# %%
X=df.drop('high_risk_flag',axis=1)
y=df['high_risk_flag']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Bernoulli Naive Bayes yapacaksak scaler kullananmaya gerek yok ama onun dışında önemli ve kullanılmalı

# %% [markdown]
# algorithm{‘auto’, ‘ball_tree’, ‘kd_tree’, ‘brute’}, default=’auto’ /
# auto : kendi karar verir
# ball_tree : dairesel olarak ayırır ve inceler (yüksek boyutlu veri setlerinde)
# kd_tree : önce x'e göre sonra y'ye göre ikiye bölme ile ilerler (20den az sütuna sahip gibi olan küçük veri setlerinde)
# brute: tek tek hepsini dener (yüzün katı kadar satıra sahip veri setlerinde)

# %% [markdown]
# weights{‘uniform’, ‘distance’}, callable or None, default=’uniform’
# uniform : komşular aynı şekilde kabul edilir ve öyle denenir
# distance : ağırlıklı oylama yapar

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5,algorithm='auto')
classifier.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=classifier.predict(X_test_scaled)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print("confusion matrix: \n ", confusion_matrix(y_pred,y_test))
print("accuracy score: ", accuracy_score(y_pred,y_test))
print("classification report: ", classification_report(y_pred,y_test))
# Out:
# confusion matrix:
#   [[124  10]
#  [  2 114]]
# accuracy score:  0.952
# classification report:                precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       134
#            1       0.92      0.98      0.95       116
#
#     accuracy                           0.95       250
#    macro avg       0.95      0.95      0.95       250
# weighted avg       0.95      0.95      0.95       250

# %%
#auto yerine kd_tree

# %%
classifier=KNeighborsClassifier(n_neighbors=5,algorithm='kd_tree') #
classifier.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier(algorithm='kd_tree')

# %%
y_pred=classifier.predict(X_test_scaled)
print("confusion matrix: \n ", confusion_matrix(y_pred,y_test))
print("accuracy score: ", accuracy_score(y_pred,y_test))
print("classification report: ", classification_report(y_pred,y_test))
# Out:
# confusion matrix:
#   [[124  10]
#  [  2 114]]
# accuracy score:  0.952
# classification report:                precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       134
#            1       0.92      0.98      0.95       116
#
#     accuracy                           0.95       250
#    macro avg       0.95      0.95      0.95       250
# weighted avg       0.95      0.95      0.95       250

# %%
#n_neighbors= yaptık

# %%
classifier=KNeighborsClassifier(n_neighbors=3,algorithm='auto')
classifier.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=classifier.predict(X_test_scaled)
print("confusion matrix: \n ", confusion_matrix(y_pred,y_test))
print("accuracy score: ", accuracy_score(y_pred,y_test))
print("classification report: ", classification_report(y_pred,y_test))
# Out:
# confusion matrix:
#   [[125   9]
#  [  1 115]]
# accuracy score:  0.96
# classification report:                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       134
#            1       0.93      0.99      0.96       116
#
#     accuracy                           0.96       250
#    macro avg       0.96      0.96      0.96       250
# weighted avg       0.96      0.96      0.96       250

# %%
df_clean1=df.copy()
kayit_yolu = r"C:\Users\merve\Desktop\PythonProject\SVMandKNN\KNN\cleaned_12-health_risk_classification.csv"
df_clean1.to_csv(kayit_yolu, index=False)
print(f"Temizlenmiş veri başarıyla kaydedildi: {kayit_yolu}")
# Out:
# Temizlenmiş veri başarıyla kaydedildi: C:\Users\merve\Desktop\PythonProject\SVMandKNN\KNN\cleaned_12-health_risk_classification.csv

# %% [markdown]
# # *SINIFLANDIRMA*

# %%
path=r'C:\Users\merve\Desktop\PythonProject\12-house_energy_regression.csv'
df_reg=pd.read_csv(path)

# %%
df_reg.head()
# Out:
#    avg_indoor_temp_change  outdoor_humidity_level  \
# 0               -0.167118                0.146714
# 1               -0.020902                0.117327
# 2                0.150419                0.364961
# 3                0.555604                0.089581
# 4                0.058209               -1.142970
#
#    daily_energy_consumption_kwh
# 0                    -14.996950
# 1                    -12.678089
# 2                     17.775455
# 3                      6.661465
# 4                    -14.195530

# %%
df_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   avg_indoor_temp_change        1000 non-null   float64
#  1   outdoor_humidity_level        1000 non-null   float64
#  2   daily_energy_consumption_kwh  1000 non-null   float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %%
df_reg.describe()
# Out:
#        avg_indoor_temp_change  outdoor_humidity_level  \
# count             1000.000000             1000.000000
# mean                 0.033186                0.056982
# std                  0.961603                1.014959
# min                 -3.241267               -2.940389
# 25%                 -0.611581               -0.651418
# 50%                  0.036043                0.047742
# 75%                  0.648317                0.714886
# max                  3.078881                3.852731
#
#        daily_energy_consumption_kwh
# count                   1000.000000
# mean                       1.766025
# std                       41.299085
# min                     -132.797922
# 25%                      -25.600072
# 50%                        1.065474
# 75%                       28.766573
# max                      138.577662

# %%
sns.scatterplot(x=df_reg['outdoor_humidity_level'],y=df_reg['daily_energy_consumption_kwh'])
plt.show()

# %%
sns.scatterplot(x=df_reg['avg_indoor_temp_change'],y=df_reg['daily_energy_consumption_kwh'])
plt.show()

# %%
df_reg.corr()
# Out:
#                               avg_indoor_temp_change  outdoor_humidity_level  \
# avg_indoor_temp_change                      1.000000                0.002584
# outdoor_humidity_level                      0.002584                1.000000
# daily_energy_consumption_kwh                0.956682                0.169557
#
#                               daily_energy_consumption_kwh
# avg_indoor_temp_change                            0.956682
# outdoor_humidity_level                            0.169557
# daily_energy_consumption_kwh                      1.000000

# %%
X=df_reg.drop('daily_energy_consumption_kwh',axis=1)
y=df_reg['daily_energy_consumption_kwh']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=15)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor=KNeighborsRegressor(n_neighbors=5,algorithm='auto')
regressor.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=regressor.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print("r2 score: ", r2_score(y_test,y_pred))
print("mean absolute error: ", mean_absolute_error(y_test,y_pred))
print("mean squared error: ", mean_squared_error(y_test,y_pred))
# Out:
# r2 score:  0.9152685146562609
# mean absolute error:  9.42143518926242
# mean squared error:  140.40201685069158

# %%
#n_neighbors=7 yaptık

# %%
regressor=KNeighborsRegressor(n_neighbors=7,algorithm='auto')
regressor.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
y_pred=regressor.predict(X_test_scaled)
print("r2 score: ", r2_score(y_test,y_pred))
print("mean absolute error: ", mean_absolute_error(y_test,y_pred))
print("mean squared error: ", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# r2 score:  0.9164863388635838
# mean absolute error:  9.331428506491209
# mean squared error:  138.3840541750219

# %%
df_clean1=df.copy()
kayit_yolu = r"C:\Users\merve\Desktop\PythonProject\SVMandKNN\KNN\cleaned_12-house_energy_regression.csv"
df_clean1.to_csv(kayit_yolu, index=False)
print(f"Temizlenmiş veri başarıyla kaydedildi: {kayit_yolu}")
# Out:
# Temizlenmiş veri başarıyla kaydedildi: C:\Users\merve\Desktop\PythonProject\SVMandKNN\KNN\cleaned_12-house_energy_regression.csv
