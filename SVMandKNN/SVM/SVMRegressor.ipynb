# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\merve\Desktop\PythonProject\diamonds.csvp')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.shape
# Out:
# (53940, 11)

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df[df['x']==0]
# Out:
#        carat        cut color clarity  depth  table  price    x     y    z
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.00  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.00  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.00  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0

# %%
df[df['y']==0]
# Out:
#        carat        cut color clarity  depth  table  price    x    y    z
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.0  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.0  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.0  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.0  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.0  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0

# %%
df[df['z']==0]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %%
len(df[df['x']==0]) , len(df[df['y']==0]) , len(df[df['z']==0])
# Out:
# (8, 7, 20)

# %%
#x,y,z büyüklükleri belirtilmemiş olanları sileceğim

# %%
df=df.drop(df[df['x']==0].index)
df=df.drop(df[df['y']==0].index)
df=df.drop(df[df['z']==0].index)  #.index drop'tan sonra bir index belirtmeliyiz.

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.shape
# Out:
# (53920, 10)

# %%
sns.pairplot(df)
plt.show()

# %%
sns.scatterplot(x=df["x"], y=df["price"])
plt.show()

# %%
sns.scatterplot(x=df["y"], y=df["price"])
plt.show()

# %%
sns.scatterplot(x=df["depth"], y=df["price"])
plt.show() #45in altı 75in üstünü çıkarabiliriz

# %%
df[(df["depth"]<75)&(df["depth"]>45)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53914 rows x 10 columns]

# %%
len(df[(df["depth"]<75)&(df["depth"]>45)])
# Out:
# 53914

# %%
len(df)
# Out:
# 53920

# %%
len(df[(df["table"]<80)&(df["table"]>40)])
# Out:
# 53919

# %%
len(df[(df["z"]<30)&(df["z"]>2)])
# Out:
# 53916

# %%
len(df[(df["y"]<20)])
# Out:
# 53918

# %%
df = df[(df["depth"]<75)&(df["depth"]>45)]
df = df[(df["table"]<80)&(df["table"]>40)]
df = df[(df["y"]<30)]
df = df[(df["z"]<30)&(df["z"]>2)]

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53907.000000  53907.000000  53907.000000  53907.000000  53907.000000
# mean       0.797628     61.749741     57.455948   3930.584470      5.731463
# std        0.473765      1.420119      2.226153   3987.202815      1.119384
# min        0.200000     50.800000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5322.000000      6.540000
# max        5.010000     73.600000     79.000000  18823.000000     10.740000
#
#                   y             z
# count  53907.000000  53907.000000
# mean       5.733292      3.539441
# std        1.111252      0.691434
# min        3.680000      2.060000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sns.scatterplot(x=df["z"], y=df["price"])
plt.show() #bu yeni grafik , eski grafik 23. satırda

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        21543
# Premium      13779
# Very Good    12080
# Good          4902
# Fair          1603
# Name: count, dtype: int64

# %%
#temiz şekilde 5 kolon var (mesela aynı kolonun çift boşluk bırakılarak yazılmış durumları yok)

# %%
df['color'].value_counts()
# Out:
# color
# G    11282
# E     9792
# F     9536
# H     8296
# D     6774
# I     5420
# J     2807
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     13059
# VS2     12250
# SI2      9184
# VS1      8167
# VVS2     5066
# VVS1     3654
# IF       1790
# I1        737
# Name: count, dtype: int64

# %%
X= df.drop(["price"],axis =1)
y= df["price"]

# %%
X.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=15)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
for col in ['cut', 'color', 'clarity']:
    X_train[col] = label_encoder.fit_transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])  #aynı standart scaler gibi

# %%
X_train.head()
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 15200   1.15    2      4        2   62.4   54.0  6.71  6.76  4.20
# 14632   1.11    3      1        2   61.3   58.0  6.66  6.61  4.07
# 19151   1.21    1      2        5   63.7   58.0  6.67  6.71  4.26
# 29299   0.30    2      5        5   61.5   58.0  4.28  4.31  2.64
# 9983    1.00    4      2        2   63.1   57.0  6.37  6.33  4.01

# %%
X_train["cut"].value_counts()
# Out:
# cut
# 2    16178
# 3    10368
# 4     9020
# 1     3666
# 0     1198
# Name: count, dtype: int64

# %%
X_test["cut"].value_counts()
# Out:
# cut
# 2    5365
# 3    3411
# 4    3060
# 1    1236
# 0     405
# Name: count, dtype: int64

# %%
X_train.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  40430.000000  40430.000000  40430.000000  40430.000000  40430.000000
# mean       0.796206      2.552708      2.594089      3.840861     61.753396
# std        0.474132      1.025958      1.702470      1.724057      1.411827
# min        0.200000      0.000000      0.000000      0.000000     52.200000
# 25%        0.400000      2.000000      1.000000      2.000000     61.100000
# 50%        0.700000      2.000000      3.000000      4.000000     61.800000
# 75%        1.040000      3.000000      4.000000      5.000000     62.500000
# max        5.010000      4.000000      6.000000      7.000000     72.200000
#
#               table             x             y             z
# count  40430.000000  40430.000000  40430.000000  40430.000000
# mean      57.448897      5.727667      5.729408      3.537283
# std        2.221713      1.119875      1.111668      0.691941
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
reg=LinearRegression()
reg.fit(X_train_scaled,y_train)
y_pred=reg.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 864.5945387870823
# R2 Score 0.8850163452280001

# %%
#r2 score yüksek,güzel bir sonuç verdi

# %%
from sklearn.svm import SVR
#bir değeri tahmin etmeye çalışırken sadece hatayı minimize etmeye çalışmaz;bir hata payını toleransla karşılayan bir güven aralığı oluşturur
#SVR() uç değerlerden etkilenmez , doğrusal olmayan verilerde modellenebilir , esnekliğini sen belirlersin

# %%
svr=SVR()
svr.fit(X_train_scaled, y_train)
y_pred=svr.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 1398.2632905135665
# R2 Score 0.49245884122391603

# %%
#lineer regresyona göre kötü bir r2 score

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001],
              'kernel': ['rbf','linear']}

# %%
grid = GridSearchCV(SVR(), param_grid, refit = True,verbose = 3,n_jobs=-1)  
#GridSearchCV:senin belirlediğin bir "parametre havuzundaki" tüm kombinasyonları tek tek dener çapraz doğrulamayla en başarılı kombinasyonu seçer.
#param_grid: parametrelerin listesi , yukarıda tanımladık
#refit = True: En iyi parametreler bulunduktan sonra, tüm eğitim veri setini kullanarak modeli bu "en iyi" ayarlarla tekrar eğitir
#verbose=3 dediğimizde totalde kaç fit yapıyor ve kaçıncı old. gösterir

# %%
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits

# %%
grid.best_params_
